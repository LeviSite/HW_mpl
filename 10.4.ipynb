# %% [markdown]
# <a href="https://colab.research.google.com/github/LeviSite/Sem-10/blob/master/Copy_of_running_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from scipy.stats import t
import seaborn as sns
import matplotlib.pyplot as plt

rv = t(1)
n = 2

vals = []
for i in range(10000):
    a = rv.rvs(size = n)
    s = np.mean(a)
    vals.append(s)
    
df = pd.DataFrame({"x": vals})
df["PDF"] = rv.pdf(df["x"])
    
sns.lineplot(data = df, x="x", y="PDF")
sns.histplot (x = vals, stat = "density")
plt.tight_layout()
plt.xlim(-5, 5)
plt.show()

# %%
import pandas as pd
import numpy as np
from scipy.stats import t
import seaborn as sns
import matplotlib.pyplot as plt

rv = t(1)
n = 5

vals = []
for i in range(10000):
    a = rv.rvs(size = n)
    s = np.mean(a)
    vals.append(s)
    
df = pd.DataFrame({"x": vals})
df["PDF"] = rv.pdf(df["x"])
    
sns.lineplot(data = df, x="x", y="PDF")
sns.histplot (x = vals, stat = "density")
plt.tight_layout()
plt.xlim(-5, 5)
plt.show()

# %%
import pandas as pd
import numpy as np
from scipy.stats import t
import seaborn as sns
import matplotlib.pyplot as plt

rv = t(1)
n = 14

vals = []
for i in range(10000):
    a = rv.rvs(size = n)
    s = np.mean(a)
    vals.append(s)
    
df = pd.DataFrame({"x": vals})
df["PDF"] = rv.pdf(df["x"])
    
sns.lineplot(data = df, x="x", y="PDF")
sns.histplot (x = vals, stat = "density")
plt.tight_layout()
plt.xlim(-5, 5)
plt.show()

# %%
import pandas as pd
import numpy as np
from scipy.stats import t
import seaborn as sns
import matplotlib.pyplot as plt

rv = t(1)
n = 100

vals = []
for i in range(10000):
    a = rv.rvs(size = n)
    s = np.mean(a)
    vals.append(s)
    
df = pd.DataFrame({"x": vals})
df["PDF"] = rv.pdf(df["x"])
    
sns.lineplot(data = df, x="x", y="PDF")
sns.histplot (x = vals, stat = "density")
plt.tight_layout()
plt.xlim(-5, 5)
plt.show()
